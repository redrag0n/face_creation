# %%
import numpy as np
import matplotlib.pyplot as plt
from model import Model
import torch
from torch.utils.data import DataLoader

from celeba_dataset import CelebaDataset, IMG_SHAPE, data_transforms
from bayessian_optimization import BayessianOptimization

# %%
DATA_DIR = '../data'
MODEL_PATH = '../models/attempt22/epoch22'
ANNOTATION_DATA_PATH = f'{DATA_DIR}/list_attr_celeba.csv'
DATA_PATH = f'{DATA_DIR}/img_align_celeba'

# %%
m = Model.load(MODEL_PATH)
# Out:
# Model parameters: 24822311

# %%
dataset = CelebaDataset(ANNOTATION_DATA_PATH, DATA_PATH, transform=data_transforms)
all_labels = np.array(list(dataset.labels))

# %%
optimizer = BayessianOptimization(m, m.conditional_vae.latent_dim_size)

# %%
labels = ['Smiling', 'Male', 'Blond_Hair']
labels_encoded = [[1 if l in labels else 0 for l in all_labels]]

# %%
optimizer.optimize(labels_encoded)
# Out:
# label torch.Size([1, 40])
# t_sampled torch.Size([1, 32])
# label torch.Size([1, 40])
# t_sampled torch.Size([1, 32])
# label torch.Size([1, 40])
# t_sampled torch.Size([1, 32])
# label torch.Size([1, 40])
# t_sampled torch.Size([1, 32])
# label torch.Size([1, 40])
# t_sampled torch.Size([1, 32])
# Score images with numbers from 1 to 10. Input scores with spaces between them
# label torch.Size([1, 40])
# t_sampled torch.Size([1, 32])
# Score image
# label torch.Size([1, 40])
# t_sampled torch.Size([1, 32])
# Score image
# label torch.Size([1, 40])
# t_sampled torch.Size([1, 32])
# Score image
# label torch.Size([1, 40])
# t_sampled torch.Size([1, 32])
# Score image
# label torch.Size([1, 40])
# t_sampled torch.Size([1, 32])
# Score image
# label torch.Size([1, 40])
# t_sampled torch.Size([1, 32])
# Score image
# label torch.Size([1, 40])
# t_sampled torch.Size([1, 32])
# Score image
# label torch.Size([1, 40])
# t_sampled torch.Size([1, 32])
# Score image
# label torch.Size([1, 40])
# t_sampled torch.Size([1, 32])
# Score image
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/zw/786ry1h11m78b82g5n1w7dlm0000gn/T/ipykernel_63530/2569368830.py in <module>
# ----> 1 optimizer.optimize(labels_encoded)
#
# ~/PycharmProjects/face_creation/bayessian_optimization.py in optimize(self, labels_encoded, n_iter, w, acquisition_type, acquisition_par)
#     163                                                         Y=self.rating[:, None],
#     164                                                         maximize=False)
# --> 165         optimizer.run_optimization(max_iter=n_iter, eps=-1)
#     166
#     167     def get_best(self):
#
# ~/opt/anaconda3/envs/face_creation/lib/python3.8/site-packages/GPyOpt/core/bo.py in run_optimization(self, max_iter, max_time, eps, context, verbosity, save_models_parameters, report_file, evaluations_file, models_file)
#     149
#     150             # --- Evaluate *f* in X, augment Y and update cost function (if needed)
# --> 151             self.evaluate_objective()
#     152
#     153             # --- Update current evaluation time and function evaluations
#
# ~/opt/anaconda3/envs/face_creation/lib/python3.8/site-packages/GPyOpt/core/bo.py in evaluate_objective(self)
#     195         Evaluates the objective
#     196         """
# --> 197         self.Y_new, cost_new = self.objective.evaluate(self.suggested_sample)
#     198         self.cost.update_cost_model(self.suggested_sample, cost_new)
#     199         self.Y = np.vstack((self.Y,self.Y_new))
#
# ~/opt/anaconda3/envs/face_creation/lib/python3.8/site-packages/GPyOpt/core/task/objective.py in evaluate(self, x)
#      48
#      49         if self.n_procs == 1:
# ---> 50             f_evals, cost_evals = self._eval_func(x)
#      51         else:
#      52             try:
#
# ~/opt/anaconda3/envs/face_creation/lib/python3.8/site-packages/GPyOpt/core/task/objective.py in _eval_func(self, x)
#      72         for i in range(x.shape[0]):
#      73             st_time    = time.time()
# ---> 74             rlt = self.func(np.atleast_2d(x[i]))
#      75             f_evals     = np.vstack([f_evals,rlt])
#      76             cost_evals += [time.time()-st_time]
#
# ~/PycharmProjects/face_creation/bayessian_optimization.py in evaluate(self, candidate)
#     132             candidate_rating = float(score)
#     133         else:
# --> 134             candidate_rating = int(score)
#     135         candidate_rating = - candidate_rating
#     136         # print('samples', self.samples.shape, candidate.shape)
#
# ValueError: invalid literal for int() with base 10: ''

# %%
21
